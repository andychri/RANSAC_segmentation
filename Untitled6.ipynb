# %%
import numpy as np
import random
import open3d as o3d
from scipy.optimize import least_squares

def ransac_cylinder_segmentation(point_cloud, max_iterations, min_inliers, specific_radius, distance_threshold_factor):
    best_model = None
    best_inliers = []

    for _ in range(max_iterations):
        # Step 2: Randomly sample points
        sample_points_indices = random.sample(range(len(point_cloud.points)), 2)
        sample_points = np.asarray(point_cloud.points)[sample_points_indices]
        
        # Step 3: Estimate cylinder axis
        point1, point2 = sample_points
        axis_direction = normalize(point2 - point1)
        
        # Step 4: Determine inliers with a fixed radius
        distance_threshold = distance_threshold_factor * specific_radius
        inliers = []
        for i, point in enumerate(point_cloud.points):
            distance = compute_perpendicular_distance(point, point1, axis_direction)
            if abs(distance - specific_radius) < distance_threshold:
                inliers.append(i)
        
        # Step 5: Update best model if current model is better
        if len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_model = (point1, axis_direction, specific_radius)
        
        # Step 6: Refine model using inliers if found enough inliers
        if len(best_inliers) >= min_inliers:
            best_model = refine_cylinder_model(point_cloud, best_inliers, best_model, specific_radius)

    return best_model, best_inliers

def compute_perpendicular_distance(point, axis_point, axis_direction):
    vec = point - axis_point
    proj_len = np.dot(vec, axis_direction)
    proj_point = axis_point + proj_len * axis_direction
    perpendicular_vec = point - proj_point
    distance = np.linalg.norm(perpendicular_vec)
    return distance

def normalize(vector):
    return vector / np.linalg.norm(vector)

def refine_cylinder_model(point_cloud, inliers, initial_model, specific_radius):
    def residuals(params, points):
        point1 = params[:3]
        axis_direction = normalize(params[3:])
        residuals = []
        for point in points:
            distance = compute_perpendicular_distance(point, point1, axis_direction)
            residuals.append(distance - specific_radius)
        return residuals
    
    initial_params = np.concatenate([initial_model[0], initial_model[1]])
    inlier_points = np.asarray(point_cloud.points)[inliers]
    result = least_squares(residuals, initial_params, args=(inlier_points,))
    refined_model = (result.x[:3], normalize(result.x[3:]), specific_radius)
    return refined_model

def segment_multiple_cylinders(point_cloud, max_iterations, min_inliers, specific_radius, distance_threshold_factor, max_cylinders):
    remaining_points = point_cloud
    cylinder_models = []
    all_inliers = []

    for _ in range(max_cylinders):
        best_model, best_inliers = ransac_cylinder_segmentation(remaining_points, max_iterations, min_inliers, specific_radius, distance_threshold_factor)
        if len(best_inliers) < min_inliers:
            break
        
        cylinder_models.append(best_model)
        all_inliers.append(best_inliers)
        
        # Remove inliers from the point cloud
        remaining_points = remaining_points.select_by_index(best_inliers, invert=True)

    return cylinder_models, all_inliers

def visualize_cylinder_segmentation(point_cloud, cylinder_models, all_inliers):
    geometries = []
    
    for i, (model, inliers) in enumerate(zip(cylinder_models, all_inliers)):
        inlier_cloud = point_cloud.select_by_index(inliers)
        outlier_cloud = point_cloud.select_by_index(inliers, invert=True)

        # Visualize the cylinder axis
        line_set = o3d.geometry.LineSet()
        cylinder_point1 = model[0]
        cylinder_point2 = model[0] + model[1] * 10  # Extend the axis for visualization
        lines = [[0, 1]]
        colors = [[1, 0, 0]]  # Red color for the axis
        line_set.points = o3d.utility.Vector3dVector([cylinder_point1, cylinder_point2])
        line_set.lines = o3d.utility.Vector2iVector(lines)
        line_set.colors = o3d.utility.Vector3dVector(colors)

        # Visualize the point clouds
        color = np.random.rand(3)
        inlier_cloud.paint_uniform_color(color)  # Random color for inliers
        geometries.append(inlier_cloud)
        geometries.append(line_set)

    # Visualize outliers as one cloud
    remaining_cloud = point_cloud.select_by_index([idx for inliers in all_inliers for idx in inliers], invert=True)
    remaining_cloud.paint_uniform_color([0.5, 0.5, 0.5])  # Grey for outliers
    geometries.append(remaining_cloud)

    o3d.visualization.draw_geometries(geometries)

# Example usage with a sample point cloud
if __name__ == "__main__":
    # Load or create a point cloud
    pcd = o3d.io.read_point_cloud("filtered1.pcd")

    # Parameters
    max_iterations = 100
    specific_radius = 0.032  # Specific radius in meters (adjust to cm by dividing by 100)
    distance_threshold_factor = 0.1  # Adjust based on your data
    min_inliers = 50  # Adjust based on your data
    max_cylinders = 2  # Adjust based on how many cylinders you expect

    cylinder_models, all_inliers = segment_multiple_cylinders(pcd, max_iterations, min_inliers, specific_radius, distance_threshold_factor, max_cylinders)
    print("Cylinder Models:", cylinder_models)
    print("Number of Cylinders Detected:", len(cylinder_models))

    # Visualize the result
    visualize_cylinder_segmentation(pcd, cylinder_models, all_inliers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 125
#     122 min_inliers = 50  # Adjust based on your data
#     123 max_cylinders = 2  # Adjust based on how many cylinders you expect
# --> 125 cylinder_models, all_inliers = segment_multiple_cylinders(pcd, max_iterations, min_inliers, specific_radius, distance_threshold_factor, max_cylinders)
#     126 print("Cylinder Models:", cylinder_models)
#     127 print("Number of Cylinders Detected:", len(cylinder_models))
#
# Cell In[2], line 71, in segment_multiple_cylinders(point_cloud, max_iterations, min_inliers, specific_radius, distance_threshold_factor, max_cylinders)
#      68 all_inliers = []
#      70 for _ in range(max_cylinders):
# ---> 71     best_model, best_inliers = ransac_cylinder_segmentation(remaining_points, max_iterations, min_inliers, specific_radius, distance_threshold_factor)
#      72     if len(best_inliers) < min_inliers:
#      73         break
#
# Cell In[2], line 34, in ransac_cylinder_segmentation(point_cloud, max_iterations, min_inliers, specific_radius, distance_threshold_factor)
#      32     # Step 6: Refine model using inliers if found enough inliers
#      33     if len(best_inliers) >= min_inliers:
# ---> 34         best_model = refine_cylinder_model(point_cloud, best_inliers, best_model, specific_radius)
#      36 return best_model, best_inliers
#
# Cell In[2], line 61, in refine_cylinder_model(point_cloud, inliers, initial_model, specific_radius)
#      59 initial_params = np.concatenate([initial_model[0], initial_model[1]])
#      60 inlier_points = np.asarray(point_cloud.points)[inliers]
# ---> 61 result = least_squares(residuals, initial_params, args=(inlier_points,))
#      62 refined_model = (result.x[:3], normalize(result.x[3:]), specific_radius)
#      63 return refined_model
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_lsq/least_squares.py:906, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     902                 J = np.atleast_2d(J)
#     904             return J
# --> 906         J0 = jac_wrapped(x0, f0)
#     908 if J0 is not None:
#     909     if J0.shape != (m, n):
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_lsq/least_squares.py:898, in least_squares.<locals>.jac_wrapped(x, f)
#     897 def jac_wrapped(x, f):
# --> 898     J = approx_derivative(fun, x, rel_step=diff_step, method=jac,
#     899                           f0=f, bounds=bounds, args=args,
#     900                           kwargs=kwargs, sparsity=jac_sparsity)
#     901     if J.ndim != 2:  # J is guaranteed not sparse.
#     902         J = np.atleast_2d(J)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# Cell In[2], line 55, in refine_cylinder_model.<locals>.residuals(params, points)
#      53 residuals = []
#      54 for point in points:
# ---> 55     distance = compute_perpendicular_distance(point, point1, axis_direction)
#      56     residuals.append(distance - specific_radius)
#      57 return residuals
#
# Cell In[2], line 43, in compute_perpendicular_distance(point, axis_point, axis_direction)
#      41 proj_point = axis_point + proj_len * axis_direction
#      42 perpendicular_vec = point - proj_point
# ---> 43 distance = np.linalg.norm(perpendicular_vec)
#      44 return distance
#
# File ~/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py:2379, in _norm_dispatcher(x, ord, axis, keepdims)
#    2375     result = op(svd(y, compute_uv=False), axis=-1)
#    2376     return result
# -> 2379 def _norm_dispatcher(x, ord=None, axis=None, keepdims=None):
#    2380     return (x,)
#    2383 @array_function_dispatch(_norm_dispatcher)
#    2384 def norm(x, ord=None, axis=None, keepdims=False):
#
# KeyboardInterrupt:
