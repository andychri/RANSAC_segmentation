# %% [markdown]
# ## Imports and Load cloud

# %%
import numpy as np
import open3d as o3d
from scipy.optimize import least_squares
from sklearn.cluster import DBSCAN
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
pcd = o3d.io.read_point_cloud("filtered2.pcd")
downpcd = pcd.voxel_down_sample(voxel_size=0.005)
points = np.asarray(downpcd.points)
downpcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.01, max_nn=30))
normals = np.asarray(downpcd.normals)

# %% [markdown]
# ## RANSAC Cone

# %%
import numpy as np

def compute_perpendicularity_score(inliers, normals, apex, axis, opening_angle):
    """
    Compute a score based on the perpendicularity of the inlier normals to the expected cone normals.
    Points with closely aligned normals get high positive scores, while misaligned ones are penalized.
    """
    if inliers.size == 0 or normals.size == 0:
        return 0

    # Compute the expected normals for the cone
    expected_normals = compute_cone_normals(inliers, apex, axis, opening_angle)
    dot_products = np.einsum('ij,ij->i', normals, expected_normals)

    # Reward alignment: scale positive contributions for well-aligned normals
    scores = 10 * np.maximum(0, dot_products - 0.8)  # Shift and scale scores to reward alignment

    # Apply penalties for misaligned normals
    penalties = -1 * (dot_products < 0.8).astype(int) * np.abs(dot_products)  # Apply strong penalties below threshold

    # Combine scores and penalties, ensuring the result reflects both alignment rewards and misalignment penalties
    total_score = np.sum(scores) + np.sum(penalties)

    return total_score


def find_apex_from_planes(point_normals):
    """
    Find the apex of the cone by intersecting three planes defined by point-normal pairs.
    """
    A = np.array([pn[:3] for pn in point_normals])  # Normals of the planes
    b = np.array([-pn[3] for pn in point_normals])  # Distances of planes
    apex = np.linalg.lstsq(A, b, rcond=None)[0]
    return apex

def calculate_axis_from_points(apex, points):
    """
    Calculate the axis of the cone as the normal of the plane defined by the normalized vectors 
    from the apex to each of the three points.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    axis = np.cross(normalized_vectors[1] - normalized_vectors[0], normalized_vectors[2] - normalized_vectors[0])
    axis /= np.linalg.norm(axis)
    return axis

def calculate_opening_angle(apex, axis, points):
    """
    Calculate the opening angle of the cone by averaging the arccosine of the dot products between the 
    normalized vectors from the apex to the points and the axis.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    angles = [np.arccos(np.clip(np.dot(vec, axis), -1, 1)) for vec in normalized_vectors]
    opening_angle = np.mean(angles)
    return opening_angle

def sample_cone(points, normals):
    """
    Sample three points and normals to define a cone candidate.
    """
    indices = np.random.choice(points.shape[0], 3, replace=False)
    sampled_points = points[indices]
    sampled_normals = normals[indices]

    # Define point-normal pairs for planes
    point_normals = np.hstack((sampled_normals, -np.einsum('ij,ij->i', sampled_normals, sampled_points)[:, np.newaxis]))

    # Find apex of the cone by intersecting planes
    apex = find_apex_from_planes(point_normals)
    
    # Calculate the cone axis from the sampled points and apex
    axis = calculate_axis_from_points(apex, sampled_points)
    
    # Calculate the opening angle
    opening_angle = calculate_opening_angle(apex, axis, sampled_points)
    
    return apex, axis, opening_angle

def ransac_cone(points, normals, threshold, iterations):
    best_inliers = []
    best_params = None
    best_score = -np.inf
    best_inlier_count = 0

    for _ in range(iterations):
        attempt = 0
        max_attempts = 100  # Maximum number of attempts to find a valid model in each iteration
        
        while attempt < max_attempts:
            attempt += 1
            
            # Sample three points and normals to define the cone
            try:
                apex, axis, opening_angle = sample_cone(points, normals)
            except:
                continue

            # Skip constraints and directly test the cone model
            break
        
        else:
            # If no valid model found within max_attempts, skip to the next RANSAC iteration
            print(f"Iteration {_}: No valid model found after {max_attempts} attempts.")
            continue

        params = [*apex, *axis, opening_angle]
        inliers = []

        for point in points:
            vector_to_point = point - apex
            projection_length = np.dot(vector_to_point, axis)
            projection = projection_length * axis
            perpendicular_distance = np.linalg.norm(vector_to_point - projection)
            expected_distance = np.tan(opening_angle) * projection_length
            
            distance = np.abs(perpendicular_distance - expected_distance)
            if distance < threshold:
                inliers.append(point)

        inliers = np.array(inliers)
        inliers_normals = normals[np.isin(points, inliers).all(axis=1)]

        if inliers.size == 0 or inliers_normals.size == 0:
            continue

        score = compute_perpendicularity_score(inliers, inliers_normals, apex, axis, opening_angle)
        print(f"Iteration: {_}, Inliers found: {len(inliers)}, Score: {score}")

        if score > best_score:
            best_score = score
            best_inliers = inliers
            best_params = params
            best_inlier_count = len(inliers)

    print(f"Best Score: {best_score}, Inliers Count: {best_inlier_count}")
    return best_params, np.array(best_inliers)

# %%
import numpy as np

def find_apex_from_planes(point_normals):
    """
    Find the apex of the cone by intersecting three planes defined by point-normal pairs.
    """
    A = np.array([pn[:3] for pn in point_normals])  # Normals of the planes
    b = np.array([-pn[3] for pn in point_normals])  # Distances of planes
    apex = np.linalg.lstsq(A, b, rcond=None)[0]
    return apex

def calculate_axis_from_points(apex, points):
    """
    Calculate the axis of the cone as the normal of the plane defined by the normalized vectors 
    from the apex to each of the three points.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    axis = np.cross(normalized_vectors[1] - normalized_vectors[0], normalized_vectors[2] - normalized_vectors[0])
    axis /= np.linalg.norm(axis)
    return axis

def calculate_opening_angle(apex, axis, points):
    """
    Calculate the opening angle of the cone by averaging the arccosine of the dot products between the 
    normalized vectors from the apex to the points and the axis.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    angles = [np.arccos(np.clip(np.dot(vec, axis), -1, 1)) for vec in normalized_vectors]
    opening_angle = np.mean(angles)
    return opening_angle

def sample_cone(points, normals):
    """
    Sample three points and normals to define a cone candidate.
    """
    indices = np.random.choice(points.shape[0], 3, replace=False)
    sampled_points = points[indices]
    sampled_normals = normals[indices]

    # Define point-normal pairs for planes
    point_normals = np.hstack((sampled_normals, -np.einsum('ij,ij->i', sampled_normals, sampled_points)[:, np.newaxis]))

    # Find apex of the cone by intersecting planes
    apex = find_apex_from_planes(point_normals)
    
    # Calculate the cone axis from the sampled points and apex
    axis = calculate_axis_from_points(apex, sampled_points)
    
    # Calculate the opening angle
    opening_angle = calculate_opening_angle(apex, axis, sampled_points)
    
    return apex, axis, opening_angle

def check_constraints(apex, axis, opening_angle, points, max_height):
    """
    Check if the cone model meets realistic constraints for angle and height, defining it as a finite cone.
    """
    # Angle constraints in degrees
    min_angle_deg = 10  # Minimum angle in degrees
    max_angle_deg = 70  # Maximum angle in degrees
    min_angle = np.deg2rad(min_angle_deg)  # Convert to radians
    max_angle = np.deg2rad(max_angle_deg)  # Convert to radians
    if not (min_angle <= opening_angle <= max_angle):
        print(f"Failed angle constraint: Opening angle = {np.rad2deg(opening_angle):.2f} degrees (Expected: {min_angle_deg:.2f} - {max_angle_deg:.2f} degrees)")
        return False

    # Height constraint: calculate the height of the cone from apex to the furthest point
    heights = np.dot(points - apex, axis)
    height = np.max(heights) - np.min(heights)
    min_height = 0.0  # Minimum height constraint
    if not (min_height <= height <= max_height):
        print(f"Failed height constraint: Height = {height:.2f} (Expected: {min_height:.2f} - {max_height:.2f})")
        return False

    return True

def ransac_cone(points, normals, threshold, iterations, max_height):
    best_inliers = []
    best_params = None
    best_score = -np.inf
    best_inlier_count = 0

    for _ in range(iterations):
        attempt = 0
        max_attempts = 100  # Maximum number of attempts to find a valid model in each iteration
        
        while attempt < max_attempts:
            attempt += 1
            
            # Sample three points and normals to define the cone
            try:
                apex, axis, opening_angle = sample_cone(points, normals)
            except:
                continue

            # Check if the sampled cone parameters meet the constraints
            if check_constraints(apex, axis, opening_angle, points, max_height):
                break  # Exit loop if a valid model is found within the constraints
        else:
            # If no valid model found within max_attempts, skip to the next RANSAC iteration
            print(f"Iteration {_}: No valid model found after {max_attempts} attempts.")
            continue

        params = [*apex, *axis, opening_angle]
        inliers = []

        # Limit projections to be within the height constraints of the cone
        for point in points:
            vector_to_point = point - apex
            projection_length = np.clip(np.dot(vector_to_point, axis), 0, max_height)  # Limit within [0, max_height]
            projection = projection_length * axis
            perpendicular_distance = np.linalg.norm(vector_to_point - projection)
            expected_distance = np.tan(opening_angle) * projection_length
            
            distance = np.abs(perpendicular_distance - expected_distance)
            if distance < threshold:
                inliers.append(point)

        inliers = np.array(inliers)
        inliers_normals = normals[np.isin(points, inliers).all(axis=1)]

        if inliers.size == 0 or inliers_normals.size == 0:
            continue

        score = compute_perpendicularity_score(inliers, inliers_normals, apex, axis, opening_angle)
        print(f"Iteration: {_}, Inliers found: {len(inliers)}, Score: {score}")

        if score > best_score:
            best_score = score
            best_inliers = inliers
            best_params = params
            best_inlier_count = len(inliers)

    print(f"Best Score: {best_score}, Inliers Count: {best_inlier_count}")
    return best_params, np.array(best_inliers)

# %%
import numpy as np

def find_apex_from_planes(point_normals):
    """
    Find the apex of the cone by intersecting three planes defined by point-normal pairs.
    """
    A = np.array([pn[:3] for pn in point_normals])  # Normals of the planes
    b = np.array([-pn[3] for pn in point_normals])  # Distances of planes
    apex = np.linalg.lstsq(A, b, rcond=None)[0]
    return apex

def calculate_axis_from_points(apex, points):
    """
    Calculate the axis of the cone as the normal of the plane defined by the normalized vectors 
    from the apex to each of the three points.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    axis = np.cross(normalized_vectors[1] - normalized_vectors[0], normalized_vectors[2] - normalized_vectors[0])
    axis /= np.linalg.norm(axis)
    return axis

def calculate_opening_angle(apex, axis, points):
    """
    Calculate the opening angle of the cone by averaging the arccosine of the dot products between the 
    normalized vectors from the apex to the points and the axis.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    angles = [np.arccos(np.clip(np.dot(vec, axis), -1, 1)) for vec in normalized_vectors]
    opening_angle = np.mean(angles)
    return opening_angle

def compute_cone_normals(points, apex, axis, opening_angle):
    """
    Compute the expected normals for points on a cone's surface given the apex, axis, and opening angle.
    """
    vectors_to_points = points - apex
    projection_lengths = np.dot(vectors_to_points, axis)
    projections = np.outer(projection_lengths, axis)
    surface_directions = vectors_to_points - projections
    expected_normals = surface_directions / np.linalg.norm(surface_directions, axis=1)[:, np.newaxis]
    return expected_normals

def sample_cone(points, normals):
    """
    Sample three points and normals to define a cone candidate.
    """
    indices = np.random.choice(points.shape[0], 3, replace=False)
    sampled_points = points[indices]
    sampled_normals = normals[indices]

    # Define point-normal pairs for planes
    point_normals = np.hstack((sampled_normals, -np.einsum('ij,ij->i', sampled_normals, sampled_points)[:, np.newaxis]))

    # Find apex of the cone by intersecting planes
    apex = find_apex_from_planes(point_normals)
    
    # Calculate the cone axis from the sampled points and apex
    axis = calculate_axis_from_points(apex, sampled_points)
    
    # Calculate the opening angle
    opening_angle = calculate_opening_angle(apex, axis, sampled_points)
    
    return apex, axis, opening_angle

def ransac_cone(points, normals, threshold, iterations):
    best_inliers = []
    best_params = None
    best_score = -np.inf
    best_inlier_count = 0

    for _ in range(iterations):
        attempt = 0
        max_attempts = 100  # Maximum number of attempts to find a valid model in each iteration
        
        while attempt < max_attempts:
            attempt += 1
            
            # Sample three points and normals to define the cone
            try:
                apex, axis, opening_angle = sample_cone(points, normals)
            except:
                continue

            break
        
        else:
            # If no valid model found within max_attempts, skip to the next RANSAC iteration
            print(f"Iteration {_}: No valid model found after {max_attempts} attempts.")
            continue

        params = [*apex, *axis, opening_angle]
        inliers = []

        for point in points:
            vector_to_point = point - apex
            projection_length = np.dot(vector_to_point, axis)
            projection = projection_length * axis
            perpendicular_distance = np.linalg.norm(vector_to_point - projection)
            expected_distance = np.tan(opening_angle) * projection_length
            
            distance = np.abs(perpendicular_distance - expected_distance)
            if distance < threshold:
                inliers.append(point)

        inliers = np.array(inliers)
        inliers_normals = normals[np.isin(points, inliers).all(axis=1)]

        if inliers.size == 0 or inliers_normals.size == 0:
            continue

        # Use the refined scoring function with penalties
        score = compute_perpendicularity_score(inliers, inliers_normals, apex, axis, opening_angle)
        print(f"Iteration: {_}, Inliers found: {len(inliers)}, Score: {score}")

        if score > best_score:
            best_score = score
            best_inliers = inliers
            best_params = params
            best_inlier_count = len(inliers)

    print(f"Best Score: {best_score}, Inliers Count: {best_inlier_count}")
    return best_params, np.array(best_inliers)

# %%
import numpy as np

def find_apex_from_planes(point_normals):
    """
    Find the apex of the cone by intersecting three planes defined by point-normal pairs.
    """
    A = np.array([pn[:3] for pn in point_normals])  # Normals of the planes
    b = np.array([-pn[3] for pn in point_normals])  # Distances of planes
    apex = np.linalg.lstsq(A, b, rcond=None)[0]
    return apex

def calculate_axis_from_points(apex, points):
    """
    Calculate the axis of the cone as the normal of the plane defined by the normalized vectors 
    from the apex to each of the three points.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    axis = np.cross(normalized_vectors[1] - normalized_vectors[0], normalized_vectors[2] - normalized_vectors[0])
    axis /= np.linalg.norm(axis)
    return axis

def calculate_opening_angle(apex, axis, points):
    """
    Calculate the opening angle of the cone by averaging the arccosine of the dot products between the 
    normalized vectors from the apex to the points and the axis.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    angles = [np.arccos(np.clip(np.dot(vec, axis), -1, 1)) for vec in normalized_vectors]
    opening_angle = np.mean(angles)
    return opening_angle

def compute_cone_normals(points, apex, axis, opening_angle):
    """
    Compute the expected normals for points on a cone's surface given the apex, axis, and opening angle.
    """
    vectors_to_points = points - apex
    projection_lengths = np.dot(vectors_to_points, axis)
    projections = np.outer(projection_lengths, axis)
    surface_directions = vectors_to_points - projections
    expected_normals = surface_directions / np.linalg.norm(surface_directions, axis=1)[:, np.newaxis]
    return expected_normals

def sample_cone(points, normals):
    """
    Sample three points and normals to define a cone candidate.
    """
    indices = np.random.choice(points.shape[0], 3, replace=False)
    sampled_points = points[indices]
    sampled_normals = normals[indices]

    # Define point-normal pairs for planes
    point_normals = np.hstack((sampled_normals, -np.einsum('ij,ij->i', sampled_normals, sampled_points)[:, np.newaxis]))

    # Find apex of the cone by intersecting planes
    apex = find_apex_from_planes(point_normals)
    
    # Calculate the cone axis from the sampled points and apex
    axis = calculate_axis_from_points(apex, sampled_points)
    
    # Calculate the opening angle
    opening_angle = calculate_opening_angle(apex, axis, sampled_points)
    
    return apex, axis, opening_angle

def ransac_cone(points, normals, threshold, iterations, max_height=20.0):
    best_inliers = []
    best_params = None
    best_score = -np.inf
    best_inlier_count = 0

    for _ in range(iterations):
        attempt = 0
        max_attempts = 100  # Maximum number of attempts to find a valid model in each iteration
        
        while attempt < max_attempts:
            attempt += 1
            
            # Sample three points and normals to define the cone
            try:
                apex, axis, opening_angle = sample_cone(points, normals)
            except:
                continue

            break  # Proceed without additional checks for simplicity
        
        else:
            # If no valid model found within max_attempts, skip to the next RANSAC iteration
            print(f"Iteration {_}: No valid model found after {max_attempts} attempts.")
            continue

        params = [*apex, *axis, opening_angle]
        inliers = []

        for point in points:
            vector_to_point = point - apex
            projection_length = np.clip(np.dot(vector_to_point, axis), 0, max_height)  # Limit within [0, max_height]
            projection = projection_length * axis
            perpendicular_distance = np.linalg.norm(vector_to_point - projection)
            expected_distance = np.tan(opening_angle) * projection_length
            
            distance = np.abs(perpendicular_distance - expected_distance)
            if distance < threshold:
                inliers.append(point)

        inliers = np.array(inliers)
        inliers_normals = normals[np.isin(points, inliers).all(axis=1)]

        if inliers.size == 0 or inliers_normals.size == 0:
            continue

        # Use the refined scoring function with penalties
        score = compute_perpendicularity_score(inliers, inliers_normals, apex, axis, opening_angle)
        print(f"Iteration: {_}, Inliers found: {len(inliers)}, Score: {score}")

        if score > best_score:
            best_score = score
            best_inliers = inliers
            best_params = params
            best_inlier_count = len(inliers)

    print(f"Best Score: {best_score}, Inliers Count: {best_inlier_count}")
    return best_params, np.array(best_inliers)

# %%
import numpy as np

def find_apex_from_planes(point_normals):
    """
    Find the apex of the cone by intersecting three planes defined by point-normal pairs.
    """
    A = np.array([pn[:3] for pn in point_normals])  # Normals of the planes
    b = np.array([-pn[3] for pn in point_normals])  # Distances of planes
    apex = np.linalg.lstsq(A, b, rcond=None)[0]
    return apex

def calculate_axis_from_points(apex, points):
    """
    Calculate the axis of the cone as the normal of the plane defined by the normalized vectors 
    from the apex to each of the three points.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    axis = np.cross(normalized_vectors[1] - normalized_vectors[0], normalized_vectors[2] - normalized_vectors[0])
    axis /= np.linalg.norm(axis)
    return axis

def calculate_opening_angle(apex, axis, points):
    """
    Calculate the opening angle of the cone by averaging the arccosine of the dot products between the 
    normalized vectors from the apex to the points and the axis.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    angles = [np.arccos(np.clip(np.dot(vec, axis), -1, 1)) for vec in normalized_vectors]
    opening_angle = np.mean(angles)
    return opening_angle

def compute_cone_normals(points, apex, axis, opening_angle):
    """
    Compute the expected normals for points on a cone's surface given the apex, axis, and opening angle.
    """
    vectors_to_points = points - apex
    projection_lengths = np.dot(vectors_to_points, axis)
    projections = np.outer(projection_lengths, axis)
    surface_directions = vectors_to_points - projections
    expected_normals = surface_directions / np.linalg.norm(surface_directions, axis=1)[:, np.newaxis]
    return expected_normals

def check_angle_constraints(opening_angle, min_angle_deg=10, max_angle_deg=70):
    """
    Check if the cone's opening angle meets realistic constraints.
    """
    min_angle = np.deg2rad(min_angle_deg)
    max_angle = np.deg2rad(max_angle_deg)
    if not (min_angle <= opening_angle <= max_angle):
        print(f"Failed angle constraint: Opening angle = {np.rad2deg(opening_angle):.2f} degrees "
              f"(Expected: {min_angle_deg:.2f} - {max_angle_deg:.2f} degrees)")
        return False
    return True

def sample_cone(points, normals):
    """
    Sample three points and normals to define a cone candidate.
    """
    indices = np.random.choice(points.shape[0], 3, replace=False)
    sampled_points = points[indices]
    sampled_normals = normals[indices]

    # Define point-normal pairs for planes
    point_normals = np.hstack((sampled_normals, -np.einsum('ij,ij->i', sampled_normals, sampled_points)[:, np.newaxis]))

    # Find apex of the cone by intersecting planes
    apex = find_apex_from_planes(point_normals)
    
    # Calculate the cone axis from the sampled points and apex
    axis = calculate_axis_from_points(apex, sampled_points)
    
    # Calculate the opening angle
    opening_angle = calculate_opening_angle(apex, axis, sampled_points)
    
    return apex, axis, opening_angle

def ransac_cone(points, normals, threshold, iterations, max_distance=0.1, min_angle_deg=20, max_angle_deg=100):
    best_inliers = []
    best_params = None
    best_score = -np.inf
    best_inlier_count = 0

    for _ in range(iterations):
        attempt = 0
        max_attempts = 100  # Maximum number of attempts to find a valid model in each iteration
        
        while attempt < max_attempts:
            attempt += 1
            
            # Sample three points and normals to define the cone
            try:
                apex, axis, opening_angle = sample_cone(points, normals)
            except:
                continue

            # Check if the opening angle meets the constraints
            if check_angle_constraints(opening_angle, min_angle_deg, max_angle_deg):
                break  # Valid cone found with angle constraints
        
        else:
            # If no valid model found within max_attempts, skip to the next RANSAC iteration
            print(f"Iteration {_}: No valid model found after {max_attempts} attempts.")
            continue

        params = [*apex, *axis, opening_angle]
        inliers = []

        for point in points:
            vector_to_point = point - apex
            projection_length = np.dot(vector_to_point, axis)  # Calculate distance along the axis
            
            # Skip points that are too far from the apex
            if projection_length < 0 or projection_length > max_distance:
                continue  # Point is outside the valid inlier range
            
            projection = projection_length * axis
            perpendicular_distance = np.linalg.norm(vector_to_point - projection)
            expected_distance = np.tan(opening_angle) * projection_length
            
            distance = np.abs(perpendicular_distance - expected_distance)
            if distance < threshold:
                inliers.append(point)

        inliers = np.array(inliers)
        inliers_normals = normals[np.isin(points, inliers).all(axis=1)]

        if inliers.size == 0 or inliers_normals.size == 0:
            continue

        # Use the refined scoring function with penalties
        score = compute_perpendicularity_score(inliers, inliers_normals, apex, axis, opening_angle)
        print(f"Iteration: {_}, Inliers found: {len(inliers)}, Score: {score}")

        if score > best_score:
            best_score = score
            best_inliers = inliers
            best_params = params
            best_inlier_count = len(inliers)

    print(f"Best Score: {best_score}, Inliers Count: {best_inlier_count}")
    return best_params, np.array(best_inliers)

# %%
import numpy as np

def find_apex_from_planes(point_normals):
    """
    Find the apex of the cone by intersecting three planes defined by point-normal pairs.
    """
    A = np.array([pn[:3] for pn in point_normals])  # Normals of the planes
    b = np.array([-pn[3] for pn in point_normals])  # Distances of planes
    apex = np.linalg.lstsq(A, b, rcond=None)[0]
    return apex

def calculate_axis_from_points(apex, points):
    """
    Calculate the axis of the cone as the normal of the plane defined by the normalized vectors 
    from the apex to each of the three points.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    axis = np.cross(normalized_vectors[1] - normalized_vectors[0], normalized_vectors[2] - normalized_vectors[0])
    axis /= np.linalg.norm(axis)
    return axis

def calculate_opening_angle(apex, axis, points):
    """
    Calculate the opening angle of the cone by averaging the arccosine of the dot products between the 
    normalized vectors from the apex to the points and the axis.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    angles = [np.arccos(np.clip(np.dot(vec, axis), -1, 1)) for vec in normalized_vectors]
    opening_angle = np.mean(angles)
    return opening_angle

def compute_cone_normals(points, apex, axis, opening_angle):
    """
    Compute the expected normals for points on a cone's surface given the apex, axis, and opening angle.
    """
    vectors_to_points = points - apex
    projection_lengths = np.dot(vectors_to_points, axis)
    projections = np.outer(projection_lengths, axis)
    surface_directions = vectors_to_points - projections
    expected_normals = surface_directions / np.linalg.norm(surface_directions, axis=1)[:, np.newaxis]
    return expected_normals

def compute_perpendicularity_score(points, normals, apex, axis, opening_angle):
    """
    Compute a score based on the perpendicularity of the inlier normals to the expected cone normals.
    Points with closely aligned normals get high positive scores, while misaligned ones are penalized.
    """
    if points.size == 0 or normals.size == 0:
        return 0

    expected_normals = compute_cone_normals(points, apex, axis, opening_angle)
    dot_products = np.einsum('ij,ij->i', normals, expected_normals)

    # Reward alignment and apply moderate penalties for misalignment
    scores = 10 * np.maximum(0, dot_products - 0.8)
    penalties = -10 * (dot_products < 0.8).astype(int) * np.abs(dot_products)

    total_score = np.sum(scores) + np.sum(penalties)
    return total_score

def compute_density_score(points, apex, axis, max_distance, num_bins=10):
    """
    Compute a density score based on the expected density distribution along the cone's height.
    Points closer to the base (maximum height) should be denser, while those near the apex should be sparser.
    """
    projection_lengths = np.dot(points - apex, axis)
    normalized_heights = projection_lengths / max_distance  # Normalize heights between 0 (apex) and 1 (base)

    # Bin the heights to assess density distribution along the cone
    bin_counts, _ = np.histogram(normalized_heights, bins=np.linspace(0, 1, num_bins + 1))

    # Calculate density score: Encourage increasing density towards the base without harsh penalties
    density_score = 0
    for i in range(1, len(bin_counts)):
        density_score += (bin_counts[i] - bin_counts[i - 1]) * 2  # Mildly reward increased density

    # Adjust score to slightly favor configurations with more points
    density_score += len(points) * 0.5  # Small reward for larger inlier sets

    return density_score

def sample_cone(points, normals):
    """
    Sample three points and normals to define a cone candidate.
    """
    indices = np.random.choice(points.shape[0], 3, replace=False)
    sampled_points = points[indices]
    sampled_normals = normals[indices]

    # Define point-normal pairs for planes
    point_normals = np.hstack((sampled_normals, -np.einsum('ij,ij->i', sampled_normals, sampled_points)[:, np.newaxis]))

    # Find apex of the cone by intersecting planes
    apex = find_apex_from_planes(point_normals)
    
    # Calculate the cone axis from the sampled points and apex
    axis = calculate_axis_from_points(apex, sampled_points)
    
    # Calculate the opening angle
    opening_angle = calculate_opening_angle(apex, axis, sampled_points)
    
    return apex, axis, opening_angle

def ransac_cone(points, normals, threshold, iterations, max_distance=20.0, min_angle_deg=10, max_angle_deg=70):
    best_inliers = []
    best_params = None
    best_score = -np.inf
    best_inlier_count = 0

    for _ in range(iterations):
        # Sample three points and normals to define the cone
        try:
            apex, axis, opening_angle = sample_cone(points, normals)
        except:
            continue

        # Skip this iteration if the opening angle does not meet the constraints
        if not check_angle_constraints(opening_angle, min_angle_deg, max_angle_deg):
            continue  # Skip to the next iteration immediately

        params = [*apex, *axis, opening_angle]
        inliers = []

        for point in points:
            vector_to_point = point - apex
            projection_length = np.dot(vector_to_point, axis)  # Calculate distance along the axis
            
            # Skip points that are too far from the apex
            if projection_length < 0 or projection_length > max_distance:
                continue  # Point is outside the valid inlier range
            
            projection = projection_length * axis
            perpendicular_distance = np.linalg.norm(vector_to_point - projection)
            expected_distance = np.tan(opening_angle) * projection_length
            
            distance = np.abs(perpendicular_distance - expected_distance)
            if distance < threshold:
                inliers.append(point)

        inliers = np.array(inliers)
        inliers_normals = normals[np.isin(points, inliers).all(axis=1)]

        if inliers.size == 0 or inliers_normals.size == 0:
            continue

        # Compute scores for the current set of inliers
        perpendicularity_score = compute_perpendicularity_score(inliers, inliers_normals, apex, axis, opening_angle)
        density_score = compute_density_score(inliers, apex, axis, max_distance)

        # Combine perpendicularity and density scores
        combined_score = perpendicularity_score + density_score
        print(f"Iteration: {_}, Inliers found: {len(inliers)}, Score: {combined_score}")

        if combined_score > best_score:
            best_score = combined_score
            best_inliers = inliers
            best_params = params
            best_inlier_count = len(inliers)

    print(f"Best Score: {best_score}, Inliers Count: {best_inlier_count}")
    return best_params, np.array(best_inliers)

# %%
import numpy as np

def find_apex_from_planes(point_normals):
    """
    Find the apex of the cone by intersecting three planes defined by point-normal pairs.
    """
    A = np.array([pn[:3] for pn in point_normals])  # Normals of the planes
    b = np.array([-pn[3] for pn in point_normals])  # Distances of planes
    apex = np.linalg.lstsq(A, b, rcond=None)[0]
    return apex

def calculate_axis_from_points(apex, points):
    """
    Calculate the axis of the cone as the normal of the plane defined by the normalized vectors 
    from the apex to each of the three points.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    axis = np.cross(normalized_vectors[1] - normalized_vectors[0], normalized_vectors[2] - normalized_vectors[0])
    axis /= np.linalg.norm(axis)
    return axis

def calculate_opening_angle(apex, axis, points):
    """
    Calculate the opening angle of the cone by averaging the arccosine of the dot products between the 
    normalized vectors from the apex to the points and the axis.
    """
    direction_vectors = [p - apex for p in points]
    normalized_vectors = [vec / np.linalg.norm(vec) for vec in direction_vectors]
    angles = [np.arccos(np.clip(np.dot(vec, axis), -1, 1)) for vec in normalized_vectors]
    opening_angle = np.mean(angles)
    return opening_angle

def is_point_inside_cone(point, apex, axis, opening_angle):
    """
    Check if a point is inside the cone based on the cone's apex, axis, and opening angle.
    """
    vector_to_point = point - apex
    projection_length = np.dot(vector_to_point, axis)
    projection = projection_length * axis
    perpendicular_distance = np.linalg.norm(vector_to_point - projection)
    expected_distance = np.tan(opening_angle) * projection_length

    # A point is inside the cone if its perpendicular distance is less than or equal to the expected distance
    return perpendicular_distance <= expected_distance

def compute_density_score(points, all_points, apex, axis, opening_angle, max_distance, num_bins=10, initial_bin_score=100):
    """
    Compute a density score based on bin scores. Each bin starts with a fixed score, 
    and points outside the cone reduce the bin score.
    """
    # Calculate projection lengths for all points close to the cone model
    projection_lengths = np.dot(all_points - apex, axis)
    normalized_heights = projection_lengths / max_distance  # Normalize heights between 0 (apex) and 1 (base)

    # Bin the heights to assess density distribution along the cone
    bin_counts, bin_edges = np.histogram(normalized_heights, bins=np.linspace(0, 1, num_bins + 1))

    # Identify inliers' projection lengths
    inlier_lengths = np.dot(points - apex, axis)
    inlier_normalized_heights = inlier_lengths / max_distance

    # Count inliers per bin
    inlier_counts, _ = np.histogram(inlier_normalized_heights, bins=bin_edges)

    # Initialize each bin score
    bin_scores = np.full(num_bins, initial_bin_score)

    # Adjust each bin's score by subtracting points outside the cone
    for i in range(num_bins):
        non_inlier_indices = np.where((normalized_heights >= bin_edges[i]) & (normalized_heights < bin_edges[i + 1]))[0]
        for idx in non_inlier_indices:
            point = all_points[idx]
            if not is_point_inside_cone(point, apex, axis, opening_angle):
                bin_scores[i] -= 1  # Subtract 1 for each point outside the cone

    # Ensure bin scores do not go negative
    bin_scores = np.maximum(bin_scores, 0)

    # Sum the scores to get the total density score
    density_score = np.sum(bin_scores)

    # Add a small reward for larger inlier sets to balance the scoring
    density_score += len(points) * 0.1  # Mildly reward configurations with more inliers

    return density_score

def sample_cone(points, normals):
    """
    Sample three points and normals to define a cone candidate.
    """
    indices = np.random.choice(points.shape[0], 3, replace=False)
    sampled_points = points[indices]
    sampled_normals = normals[indices]

    # Define point-normal pairs for planes
    point_normals = np.hstack((sampled_normals, -np.einsum('ij,ij->i', sampled_normals, sampled_points)[:, np.newaxis]))

    # Find apex of the cone by intersecting planes
    apex = find_apex_from_planes(point_normals)
    
    # Calculate the cone axis from the sampled points and apex
    axis = calculate_axis_from_points(apex, sampled_points)
    
    # Calculate the opening angle
    opening_angle = calculate_opening_angle(apex, axis, sampled_points)
    
    return apex, axis, opening_angle

def ransac_cone(points, normals, threshold, iterations, max_distance=0.02, min_angle_deg=10, max_angle_deg=70):
    best_inliers = []
    best_params = None
    best_score = -np.inf
    best_inlier_count = 0

    for _ in range(iterations):
        # Sample three points and normals to define the cone
        try:
            apex, axis, opening_angle = sample_cone(points, normals)
        except:
            continue

        # Skip this iteration if the opening angle does not meet the constraints
        if not check_angle_constraints(opening_angle, min_angle_deg, max_angle_deg):
            continue  # Skip to the next iteration immediately

        params = [*apex, *axis, opening_angle]
        inliers = []

        for point in points:
            vector_to_point = point - apex
            projection_length = np.dot(vector_to_point, axis)  # Calculate distance along the axis
            
            # Skip points that are too far from the apex
            if projection_length < 0 or projection_length > max_distance:
                continue  # Point is outside the valid inlier range
            
            projection = projection_length * axis
            perpendicular_distance = np.linalg.norm(vector_to_point - projection)
            expected_distance = np.tan(opening_angle) * projection_length
            
            distance = np.abs(perpendicular_distance - expected_distance)
            if distance < threshold:
                inliers.append(point)

        inliers = np.array(inliers)

        if inliers.size == 0:
            continue

        # Compute the density score using the adjusted bin scoring approach
        density_score = compute_density_score(inliers, points, apex, axis, opening_angle, max_distance)

        # Use only the density score for evaluation
        combined_score = density_score
        print(f"Iteration: {_}, Inliers found: {len(inliers)}, Score: {combined_score}")

        if combined_score > best_score:
            best_score = combined_score
            best_inliers = inliers
            best_params = params
            best_inlier_count = len(inliers)

    print(f"Best Score: {best_score}, Inliers Count: {best_inlier_count}")
    return best_params, np.array(best_inliers)

# %% [markdown]
# ## 3D Mesh

# %%
cone_params, cone_inliers =  ransac_cone(points, normals, threshold=0.01, iterations=20000)
# Out:
# Failed angle constraint: Opening angle = 5.02 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 2, Inliers found: 209, Score: 543.9
# Failed angle constraint: Opening angle = 156.92 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 6.10 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 90.97 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 6, Inliers found: 43, Score: 341.3
# Failed angle constraint: Opening angle = 140.96 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 116.94 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 154.26 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 12, Inliers found: 98, Score: 542.8
# Failed angle constraint: Opening angle = 5.98 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 80.35 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 167.68 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 142.73 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 73.10 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.72 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.22 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 21, Inliers found: 22, Score: 602.2
# Failed angle constraint: Opening angle = 86.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 131.48 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 174.79 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 73.97 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 169.52 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 28, Inliers found: 11, Score: 611.1
# Failed angle constraint: Opening angle = 176.84 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.92 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 127.11 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 110.34 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 171.59 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.69 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 112.56 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 126.09 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 38, Inliers found: 26, Score: 894.6
# Iteration: 39, Inliers found: 159, Score: 339.9
# Failed angle constraint: Opening angle = 90.05 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 101.77 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 156.47 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.25 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 85.11 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 89.17 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.24 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 99.33 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 127.81 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 148.76 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 70.55 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 120.27 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 55, Inliers found: 18, Score: 788.8
# Failed angle constraint: Opening angle = 142.49 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 71.27 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 58, Inliers found: 21, Score: 890.1
# Failed angle constraint: Opening angle = 0.82 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 60, Inliers found: 99, Score: 503.9
# Failed angle constraint: Opening angle = 176.06 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 151.44 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 154.04 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 111.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 126.77 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.57 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 68, Inliers found: 167, Score: 616.7
# Failed angle constraint: Opening angle = 106.32 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 162.92 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 89.76 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 158.61 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 162.24 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.18 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.75 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 70.46 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 74.36 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 151.44 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 166.32 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 90.74 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 83, Inliers found: 23, Score: 740.3
# Failed angle constraint: Opening angle = 140.03 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 123.33 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 4.00 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 171.85 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 89, Inliers found: 242, Score: 199.2
# Iteration: 90, Inliers found: 61, Score: 478.1
# Failed angle constraint: Opening angle = 154.30 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 120.38 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 93, Inliers found: 198, Score: 197.8
# Failed angle constraint: Opening angle = 122.72 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 115.03 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 160.54 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 111.43 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 99, Inliers found: 177, Score: 537.7
# Failed angle constraint: Opening angle = 79.82 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 99.10 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.23 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 166.36 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 147.35 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 107, Inliers found: 116, Score: 482.6
# Failed angle constraint: Opening angle = 74.97 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 105.45 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 148.14 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 165.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 6.60 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 116, Inliers found: 210, Score: 53.0
# Failed angle constraint: Opening angle = 172.86 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 170.86 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 119, Inliers found: 123, Score: 683.3
# Failed angle constraint: Opening angle = 107.16 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 121, Inliers found: 235, Score: 317.5
# Failed angle constraint: Opening angle = 6.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 130.79 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 89.63 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.03 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 127, Inliers found: 156, Score: 493.6
# Failed angle constraint: Opening angle = 172.48 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 93.43 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 141.73 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 131, Inliers found: 6, Score: 997.6
# Failed angle constraint: Opening angle = 167.15 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.73 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.57 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 105.29 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.76 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 95.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 171.70 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 122.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 152.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.70 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 128.64 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.63 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.29 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 148, Inliers found: 33, Score: 963.3
# Failed angle constraint: Opening angle = 85.47 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 122.81 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 73.50 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 154, Inliers found: 131, Score: 13.100000000000001
# Failed angle constraint: Opening angle = 130.43 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 146.51 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 164.68 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 158, Inliers found: 23, Score: 518.3
# Iteration: 159, Inliers found: 65, Score: 410.5
# Iteration: 161, Inliers found: 123, Score: 793.3
# Failed angle constraint: Opening angle = 84.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 153.77 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 164, Inliers found: 46, Score: 916.6
# Failed angle constraint: Opening angle = 6.98 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 130.98 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 139.29 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 111.49 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 140.41 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 165.61 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 172, Inliers found: 154, Score: 259.4
# Failed angle constraint: Opening angle = 166.11 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 5.84 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 169.14 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 92.00 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 148.58 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.92 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 180, Inliers found: 86, Score: 557.6
# Failed angle constraint: Opening angle = 132.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 114.44 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 179.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 154.55 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 175.06 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 125.24 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 150.39 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.90 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 141.00 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 76.98 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 167.90 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 195, Inliers found: 108, Score: 507.8
# Failed angle constraint: Opening angle = 167.42 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 107.74 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 88.19 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 84.97 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.92 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 203, Inliers found: 223, Score: 574.3
# Iteration: 205, Inliers found: 105, Score: 451.5
# Failed angle constraint: Opening angle = 115.98 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 162.53 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 119.60 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 95.93 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 109.44 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 132.52 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 4.06 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 106.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 71.78 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 109.85 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 130.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.59 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 154.56 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 220, Inliers found: 126, Score: 504.6
# Failed angle constraint: Opening angle = 150.21 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 172.19 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 82.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 89.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 8.78 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 177.26 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 132.02 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 2.97 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 87.53 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 231, Inliers found: 45, Score: 168.5
# Failed angle constraint: Opening angle = 99.27 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 153.49 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.10 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 135.31 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 179.53 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 129.80 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.03 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 156.97 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 242, Inliers found: 50, Score: 214.0
# Failed angle constraint: Opening angle = 174.61 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 245, Inliers found: 276, Score: 69.6
# Failed angle constraint: Opening angle = 109.12 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 93.95 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 163.27 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.41 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 107.60 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 151.74 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 253, Inliers found: 160, Score: 360.0
# Failed angle constraint: Opening angle = 75.13 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.29 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 159.81 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 150.87 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 171.12 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 147.30 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.72 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 263, Inliers found: 15, Score: 975.5
# Failed angle constraint: Opening angle = 172.95 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 168.25 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 133.97 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 268, Inliers found: 125, Score: 524.5
# Failed angle constraint: Opening angle = 175.05 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 121.40 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 158.40 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 5.55 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 125.55 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 158.54 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 142.10 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 137.94 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 163.44 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 111.39 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 147.05 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 5.04 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 286, Inliers found: 9, Score: 793.9
# Failed angle constraint: Opening angle = 175.80 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 131.31 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 290, Inliers found: 3, Score: 944.3
# Failed angle constraint: Opening angle = 102.08 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 90.90 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 170.83 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 82.05 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 168.90 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 8.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 130.55 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 132.86 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 300, Inliers found: 227, Score: 399.7
# Failed angle constraint: Opening angle = 154.81 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.39 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 160.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 125.54 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 144.06 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 141.56 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 75.26 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 138.52 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 157.58 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 314, Inliers found: 56, Score: 731.6
# Failed angle constraint: Opening angle = 129.19 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 318, Inliers found: 148, Score: 450.8
# Failed angle constraint: Opening angle = 9.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 0.19 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.59 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 8.59 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.60 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 96.93 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 88.04 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 82.59 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 149.67 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 159.08 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 158.96 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 332, Inliers found: 109, Score: 572.9
# Failed angle constraint: Opening angle = 108.80 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.54 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 147.05 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 111.51 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 131.55 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 338, Inliers found: 183, Score: 482.3
# Iteration: 339, Inliers found: 15, Score: 545.5
# Failed angle constraint: Opening angle = 134.52 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.75 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 343, Inliers found: 214, Score: 21.400000000000002
# Failed angle constraint: Opening angle = 106.70 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 159.97 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 346, Inliers found: 67, Score: 473.7
# Failed angle constraint: Opening angle = 74.06 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 348, Inliers found: 79, Score: 482.9
# Failed angle constraint: Opening angle = 101.69 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 155.64 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 352, Inliers found: 268, Score: 594.8
# Failed angle constraint: Opening angle = 5.11 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 354, Inliers found: 66, Score: 611.6
# Failed angle constraint: Opening angle = 88.07 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 142.89 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 158.83 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.53 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 359, Inliers found: 275, Score: 158.5
# Iteration: 360, Inliers found: 138, Score: 581.8
# Iteration: 361, Inliers found: 2, Score: 965.2
# Failed angle constraint: Opening angle = 7.84 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 71.45 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.96 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 116.81 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 78.67 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 369, Inliers found: 142, Score: 447.2
# Failed angle constraint: Opening angle = 133.52 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 374, Inliers found: 137, Score: 658.7
# Iteration: 375, Inliers found: 28, Score: 829.8
# Failed angle constraint: Opening angle = 121.33 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 152.01 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.52 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 379, Inliers found: 146, Score: 24.6
# Failed angle constraint: Opening angle = 163.10 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 166.47 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 101.95 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.53 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 116.66 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 72.95 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 117.30 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 2.77 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 388, Inliers found: 193, Score: 19.3
# Failed angle constraint: Opening angle = 90.58 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.50 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 132.70 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 393, Inliers found: 191, Score: 465.1
# Failed angle constraint: Opening angle = 104.74 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 8.57 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 154.89 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 76.66 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 138.55 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.88 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 123.30 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 402, Inliers found: 284, Score: 177.4
# Failed angle constraint: Opening angle = 96.51 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 167.22 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 106.36 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 407, Inliers found: 50, Score: 398.0
# Failed angle constraint: Opening angle = 105.87 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 142.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.45 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 75.63 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.74 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.36 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 4.76 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.19 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 166.48 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 122.13 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.37 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 171.10 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 137.75 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 5.92 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 149.14 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 123.56 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 140.84 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 432, Inliers found: 73, Score: 467.3
# Failed angle constraint: Opening angle = 150.22 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 125.73 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 108.72 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 107.84 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 4.63 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.04 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 0.02 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 129.92 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 167.97 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 83.89 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 130.78 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 92.43 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 76.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 135.73 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.68 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 450, Inliers found: 7, Score: 169.7
# Iteration: 451, Inliers found: 185, Score: 441.5
# Failed angle constraint: Opening angle = 72.61 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 114.35 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 94.60 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 171.81 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 99.31 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 150.84 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 459, Inliers found: 203, Score: 20.3
# Failed angle constraint: Opening angle = 94.18 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 461, Inliers found: 144, Score: 752.4
# Failed angle constraint: Opening angle = 162.96 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.76 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 159.42 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 139.75 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 165.79 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 469, Inliers found: 44, Score: 515.4
# Failed angle constraint: Opening angle = 119.46 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 472, Inliers found: 8, Score: 996.8
# Failed angle constraint: Opening angle = 158.45 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 167.01 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 174.35 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 145.27 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 75.18 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 113.80 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 481, Inliers found: 54, Score: 387.4
# Failed angle constraint: Opening angle = 141.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 118.76 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 78.60 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 134.05 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 487, Inliers found: 1, Score: 926.1
# Failed angle constraint: Opening angle = 101.92 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 4.02 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.02 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 491, Inliers found: 127, Score: 898.7
# Failed angle constraint: Opening angle = 91.33 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 115.77 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 71.24 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 125.68 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 2.27 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 144.45 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 146.96 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 500, Inliers found: 115, Score: 501.5
# Failed angle constraint: Opening angle = 179.77 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 125.23 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.78 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 120.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 131.67 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 506, Inliers found: 197, Score: 441.7
# Failed angle constraint: Opening angle = 115.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 93.95 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 168.54 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 175.35 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 175.53 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.87 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 134.50 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.90 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.45 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 157.61 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 111.42 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 175.50 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 522, Inliers found: 197, Score: 190.7
# Failed angle constraint: Opening angle = 107.20 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 164.33 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 154.30 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 526, Inliers found: 155, Score: 208.5
# Failed angle constraint: Opening angle = 7.12 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 157.02 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.44 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 159.64 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.53 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 533, Inliers found: 128, Score: 814.8
# Iteration: 534, Inliers found: 49, Score: 733.9
# Failed angle constraint: Opening angle = 160.48 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 173.78 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 103.83 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 143.71 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 539, Inliers found: 155, Score: 148.5
# Failed angle constraint: Opening angle = 157.89 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 154.52 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 542, Inliers found: 13, Score: 666.3
# Failed angle constraint: Opening angle = 70.46 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 150.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.48 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 101.59 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 548, Inliers found: 150, Score: 247.0
# Failed angle constraint: Opening angle = 146.94 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 171.85 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 4.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 4.23 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 554, Inliers found: 28, Score: 535.8
# Iteration: 555, Inliers found: 81, Score: 486.1
# Iteration: 556, Inliers found: 65, Score: 725.5
# Failed angle constraint: Opening angle = 170.69 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 558, Inliers found: 127, Score: 507.7
# Iteration: 559, Inliers found: 93, Score: 671.3
# Iteration: 560, Inliers found: 76, Score: 891.6
# Failed angle constraint: Opening angle = 136.80 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 88.55 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 174.27 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.34 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 131.87 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 145.22 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 0.29 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 158.66 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 72.65 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 175.98 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 8.39 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 137.65 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 577, Inliers found: 54, Score: 576.4
# Failed angle constraint: Opening angle = 119.76 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 71.37 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 120.07 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 84.26 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 170.86 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.12 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 128.23 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 149.67 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 117.67 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 122.18 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 86.48 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 99.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 133.22 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 117.19 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 91.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 105.10 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 99.60 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 116.88 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 156.15 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 99.18 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.00 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 91.66 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 95.15 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 149.10 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 606, Inliers found: 15, Score: 853.5
# Failed angle constraint: Opening angle = 156.68 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 163.11 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 98.07 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 611, Inliers found: 150, Score: 452.0
# Failed angle constraint: Opening angle = 152.18 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 70.92 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 75.34 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 152.80 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 162.78 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.61 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 141.86 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 93.77 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 174.30 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 622, Inliers found: 68, Score: 578.8
# Failed angle constraint: Opening angle = 2.90 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 131.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 106.97 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.23 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 85.01 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 0.54 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 156.63 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 631, Inliers found: 116, Score: 603.6
# Failed angle constraint: Opening angle = 128.80 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 70.09 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 130.18 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 636, Inliers found: 206, Score: 624.6
# Failed angle constraint: Opening angle = 129.58 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 141.15 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.55 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 641, Inliers found: 272, Score: 127.2
# Iteration: 642, Inliers found: 88, Score: 738.8
# Iteration: 643, Inliers found: 114, Score: 420.4
# Failed angle constraint: Opening angle = 176.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.30 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 71.88 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 647, Inliers found: 56, Score: 851.6
# Failed angle constraint: Opening angle = 158.47 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 649, Inliers found: 46, Score: 585.6
# Failed angle constraint: Opening angle = 169.86 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 651, Inliers found: 215, Score: 163.5
# Failed angle constraint: Opening angle = 125.19 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 122.24 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 119.81 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 655, Inliers found: 6, Score: 778.6
# Failed angle constraint: Opening angle = 72.44 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 127.87 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 0.02 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 0.09 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.79 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 133.27 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 157.50 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 0.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 138.78 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.85 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 113.48 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.09 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.82 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 671, Inliers found: 200, Score: 576.0
# Iteration: 672, Inliers found: 23, Score: 971.3
# Failed angle constraint: Opening angle = 151.49 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 88.11 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.55 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 108.74 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.40 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 74.03 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 135.49 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 2.05 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.14 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 172.01 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 140.02 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 688, Inliers found: 2, Score: 991.2
# ...
# Failed angle constraint: Opening angle = 72.94 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19741, Inliers found: 59, Score: 43.9
# Failed angle constraint: Opening angle = 160.74 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 160.23 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 177.19 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 177.86 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 156.52 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19749, Inliers found: 246, Score: 24.6
# Iteration: 19750, Inliers found: 72, Score: 853.2
# Failed angle constraint: Opening angle = 125.76 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 83.46 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 98.91 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.94 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 131.17 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 118.94 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 162.80 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 144.33 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 146.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 116.58 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.99 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19768, Inliers found: 242, Score: 28.200000000000003
# Failed angle constraint: Opening angle = 125.90 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 139.77 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 169.71 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.37 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 146.60 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.62 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 152.36 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19776, Inliers found: 111, Score: 403.1
# Iteration: 19777, Inliers found: 28, Score: 310.8
# Failed angle constraint: Opening angle = 168.25 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 105.27 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 164.61 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 118.09 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19784, Inliers found: 97, Score: 771.7
# Iteration: 19785, Inliers found: 26, Score: 551.6
# Failed angle constraint: Opening angle = 125.34 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 110.24 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19789, Inliers found: 154, Score: 245.4
# Iteration: 19792, Inliers found: 71, Score: 810.1
# Failed angle constraint: Opening angle = 6.52 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 162.15 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 111.61 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 136.79 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19797, Inliers found: 46, Score: 419.6
# Iteration: 19799, Inliers found: 6, Score: 739.6
# Iteration: 19800, Inliers found: 153, Score: 443.3
# Failed angle constraint: Opening angle = 157.35 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.77 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19807, Inliers found: 169, Score: 528.9
# Failed angle constraint: Opening angle = 127.39 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 89.23 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19810, Inliers found: 161, Score: 637.1
# Failed angle constraint: Opening angle = 9.44 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 152.90 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 157.26 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 85.43 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 82.96 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19818, Inliers found: 253, Score: 25.3
# Iteration: 19819, Inliers found: 218, Score: 509.8
# Failed angle constraint: Opening angle = 141.64 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 0.77 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19822, Inliers found: 6, Score: 715.6
# Failed angle constraint: Opening angle = 115.29 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.24 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 166.71 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 168.82 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 114.48 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19829, Inliers found: 113, Score: 411.3
# Iteration: 19830, Inliers found: 300, Score: 449.0
# Iteration: 19831, Inliers found: 101, Score: 839.1
# Failed angle constraint: Opening angle = 74.21 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19833, Inliers found: 102, Score: 838.2
# Failed angle constraint: Opening angle = 158.24 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 105.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 159.80 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 160.01 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 155.86 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19842, Inliers found: 12, Score: 1.2000000000000002
# Iteration: 19845, Inliers found: 15, Score: 738.5
# Failed angle constraint: Opening angle = 164.95 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 148.25 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19849, Inliers found: 122, Score: 761.2
# Iteration: 19851, Inliers found: 68, Score: 606.8
# Failed angle constraint: Opening angle = 175.47 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 116.84 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.83 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 171.41 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 158.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 3.69 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19860, Inliers found: 184, Score: 48.400000000000006
# Failed angle constraint: Opening angle = 9.98 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19862, Inliers found: 56, Score: 659.6
# Failed angle constraint: Opening angle = 162.92 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 128.87 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 156.37 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 127.68 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 4.19 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19870, Inliers found: 15, Score: 922.5
# Iteration: 19871, Inliers found: 23, Score: 876.3
# Failed angle constraint: Opening angle = 150.30 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 152.84 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 156.05 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 94.50 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 147.39 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 112.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 177.19 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 120.96 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19880, Inliers found: 4, Score: 545.4
# Failed angle constraint: Opening angle = 6.77 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 97.49 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 106.37 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 141.13 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.87 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 71.61 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 91.52 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 132.36 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 132.95 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 78.62 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.37 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 142.96 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 9.22 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 6.06 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 168.77 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 8.11 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 126.43 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 118.29 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 143.69 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 2.18 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 175.68 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19913, Inliers found: 55, Score: 522.5
# Failed angle constraint: Opening angle = 86.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 149.13 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19916, Inliers found: 103, Score: 944.3
# Failed angle constraint: Opening angle = 159.32 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 70.12 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 2.85 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 84.59 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 139.67 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19927, Inliers found: 122, Score: 731.2
# Failed angle constraint: Opening angle = 123.58 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 168.16 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 150.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 170.84 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19933, Inliers found: 203, Score: 72.3
# Failed angle constraint: Opening angle = 175.00 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 149.71 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19937, Inliers found: 80, Score: 495.0
# Iteration: 19938, Inliers found: 305, Score: 204.5
# Iteration: 19939, Inliers found: 311, Score: 31.1
# Failed angle constraint: Opening angle = 78.58 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 158.75 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 118.35 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 5.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.37 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 149.47 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 145.38 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 144.28 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19952, Inliers found: 56, Score: 937.6
# Failed angle constraint: Opening angle = 172.21 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 145.41 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 142.84 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 147.69 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 124.27 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19960, Inliers found: 171, Score: 360.1
# Iteration: 19961, Inliers found: 94, Score: 867.4
# Failed angle constraint: Opening angle = 179.96 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 147.00 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19964, Inliers found: 13, Score: 603.3
# Failed angle constraint: Opening angle = 80.70 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 115.31 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 115.36 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 142.03 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 176.00 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19970, Inliers found: 160, Score: 726.0
# Iteration: 19971, Inliers found: 28, Score: 829.8
# Iteration: 19972, Inliers found: 74, Score: 782.4
# Failed angle constraint: Opening angle = 135.30 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19974, Inliers found: 56, Score: 568.6
# Failed angle constraint: Opening angle = 3.43 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 104.62 degrees (Expected: 10.00 - 70.00 degrees)
# Iteration: 19979, Inliers found: 153, Score: 379.3
# Failed angle constraint: Opening angle = 93.96 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 2.28 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 178.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 151.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 110.00 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 157.32 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 134.29 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 134.26 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 144.97 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 1.96 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 145.58 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 161.54 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 174.99 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 160.67 degrees (Expected: 10.00 - 70.00 degrees)
# Failed angle constraint: Opening angle = 7.09 degrees (Expected: 10.00 - 70.00 degrees)
# Best Score: 1001.2, Inliers Count: 12

# %% [markdown]
# ## Visualization

# %%
cone_cloud = o3d.geometry.PointCloud()
cone_cloud.points = o3d.utility.Vector3dVector(cone_inliers)
cone_cloud.paint_uniform_color([0,1,0])

#cone_mesh = create_cone_mesh(cone_params)
#cone_mesh.paint_uniform_color([0.7, 1, 0.7])

downpcd.paint_uniform_color([0,0,0])
# Out:
# PointCloud with 4084 points.

# %%
o3d.visualization.draw_geometries([downpcd, cone_cloud])
